# %% [markdown]
# # Chapter 6 - Other Popular Machine Learning Methods
# ## Segment 4 - Decision tree models with CART (Classification And Regression Tree)
#
# ### Decision Trees

# %%
import os

# os.environ["path"]

# %%
# os.environ["path"]=os.environ["path"]+";C:\\Program Files (x86)\\Graphviz2.38\\bin"

# %%
# os.environ["path"]

# %%
import sklearn.datasets as datasets
import pandas as pd
from sklearn import metrics

# %% [markdown]
# ### Preparing the data

# %%
iris=datasets.load_iris()

df = pd.DataFrame(iris.data, columns= iris.feature_names)

y = pd.DataFrame(iris.target)

y.columns = ['labels']

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.labels.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: labels, dtype: int64

# %%
y
# Out:
#      labels
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 1 columns]

# %% [markdown]
# ### The decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()

dtree.fit(df, y)
# Out:
# DecisionTreeClassifier()

# %%
# For Displaying Decision Tree
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
from pydotplus import graph_from_dot_data

# To display entire tree
dot_data = StringIO()
# Create graph Visualization based on decison tree and output file
export_graphviz(dtree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
# Create graph from dot data values
graph = graph_from_dot_data(dot_data.getvalue()) 
# Save PDF file
graph.write_pdf("DecisionTree.pdf")
# Display decision tree image
Image(graph.create_png())
